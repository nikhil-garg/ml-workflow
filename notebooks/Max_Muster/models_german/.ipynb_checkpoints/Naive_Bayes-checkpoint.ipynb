# %% [markdown]
# This is the actual model of the Arag Project and may provide you with some ideas.
# Of course the code will not compile as the imported data does not exist in your folder.
# This model can be seen as a starting point using Naive Bayes and SVC support vector machines.

# %%
# Do not run this line more than once! Otherwise restart kernel
import os
print('Initial wdir: ' + os.getcwd())
os.chdir('../../../')
print('Current wdir: ' + os.getcwd())
# Out:
# Initial wdir: C:\Users\X053269\Repos\Template - ML\notebooks\Renato\models_german
# Current wdir: C:\Users\X053269\Repos\Template - ML

# %%
from src.utils.exploration import test_model, cross_validation
from src.utils.evaluation import plot_confusion_matrix, plot_learning_curve, auc_plot, wrongly_classified

from src.data_extraction import load_data, save_data
from sklearn.metrics import (log_loss, f1_score, accuracy_score, average_precision_score, precision_score,
                             recall_score, roc_auc_score, mean_squared_error, r2_score, confusion_matrix, classification_report)
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', -1)
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
import pprint as pp
import itertools

# %%
# Create different data sets. One test set for every language and a combined one.
# Furthermore train sets containing all labels and one with true labels only.

def valid_label(x, labels):
    if x in labels:
        return True
    else:
        return False
    
    
labels = ['RSV-Arbeitsrecht', 'RSV-Vertragsrecht', 'RSV-Immobilienrecht', 'RSV-Haft- & Sozialversicherungsrecht', 'RSV-Verkehrs- & Strafrecht']
df_joined = load_data("./data/processed/processed_2018-11-05.pkl")
# get whole corpus
corpus = df_joined['lemma_clear']

# row true_label contains all the different labels found in ClaimsCore.
x_t, y_t = (df_joined[df_joined.apply(lambda row: valid_label(row['true_label'], labels), axis=1) & (df_joined['language'] == 'de')]['lemma_clear'],
            df_joined[df_joined.apply(lambda row: valid_label(row['true_label'], labels), axis=1) & (df_joined['language'] == 'de')]['true_label'])
# row label only containes the the 5 selected labels
x_a, y_a = (df_joined[pd.notna(df_joined['label']) & (df_joined['language'] == 'de')]['lemma_clear'],
            df_joined[pd.notna(df_joined['label']) & (df_joined['language'] == 'de')]['label'])

# split train and validation set
x_train_t, x_test_t, y_train_t, y_test_t = train_test_split(x_t, y_t,
                                                            test_size=0.2,
                                                            random_state=11101)

# make sure to generate a set with only true labels in the validation set
index = pd.Int64Index(x_test_t.index.values, dtype=np.int64)
new_index = pd.Int64Index(x_a.index.values).difference(index)
x_train_a = x_a.loc[new_index]
y_train_a = y_a.loc[new_index]

# %%
class_weight = {'RSV-Vertragsrecht': 1./260,
               'RSV-Arbeitsrecht': 1./86,
               'RSV-Haft- & Sozialversicherungsrecht': 1./64,
               'RSV-Immobilienrecht': 1./84,
               'RSV-Verkehrs- & Strafrecht': 1./158}

# %%
list_model = [(Pipeline([('Embedding', CountVectorizer()),
                         ('clf', MultinomialNB(alpha=0.22))]),
               'Multinomial Naive Bayes'),
              (Pipeline([('Embedding', CountVectorizer()),
                         ('Feature Transform', TfidfTransformer()),
                         ('clf', MultinomialNB(alpha=0.03))]),
               'Naive Bayes with tfidf'),
              (Pipeline([('Embedding', CountVectorizer()),
                         ('Feature Transform', TfidfTransformer()),
                         ('clf', SVC(C=5, gamma=0.1, kernel='rbf', class_weight='balanced'))]),
               'SVC'),
             (Pipeline([('Embedding', CountVectorizer()),
                         ('Feature Transform', TfidfTransformer()),
                         ('clf', SVC(C=650, gamma=0.1, kernel='rbf', class_weight=class_weight))]),
               'SVC'),
             (Pipeline([('Embedding', CountVectorizer()),
                         ('Feature Transform', TfidfTransformer()),
                         ('clf', SVC(C=1.8370, gamma=0.3343, kernel='rbf', class_weight='balanced'))]),
               'SVC')]

# %%
for model in list_model:
    test_model(model[0], model[1], x_train_a, y_train_a, x_test_t, y_test_t, details=True)
# Out:
# #############################################
#  model: Multinomial Naive Bayes
# #############################################
# the list of steps and parameters in the pipeline
#
# Embedding: CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)
#
# clf: MultinomialNB(alpha=0.22, class_prior=None, fit_prior=True)
#
# accuracy on test set:
#  0.845 %
#
# accuracy on train set:
#  0.97442143727162 %
#
# classification report:
#                                        precision    recall  f1-score   support
#
#                     RSV-Arbeitsrecht       0.79      0.94      0.86        97
# ...

# %% [markdown]
# # Cross Validation

# %%
model_cv = Pipeline([('Embedding', CountVectorizer()),
                         ('F_T', TfidfTransformer()),
                          ('clf', SVC(C=5, gamma=0.1, kernel='rbf', class_weight=class_weight))])
model_name = 'Naive Bayes with tfidf'

# %%
param_grid = {"clf__gamma": [0.01, 0.05, 0.1, 0.15],
              "clf__C": [4, 5, 6]
         }

# %%
cross_validation(model_cv, model_name, param_grid, x_a, y_a, folds=10, visualize=False, n_jobs=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3be667fc17ef> in <module>
# ----> 1 cross_validation(model_cv, param_grid, x_a, y_a, folds=10, visualize=False, n_jobs=3)
#
# NameError: name 'model_cv' is not defined

# %% [markdown]
# #  Learning Curve

# %%
for model in list_model:
    plot_learning_curve(model[0], model[1], x_t, y_t, n_jobs=3, cv=5)

# %% [markdown]
# # Bayesian Optimization

# %%
from bayes_opt import BayesianOptimization
from matplotlib import gridspec
from sklearn.model_selection import cross_validate

# %%
# define the scoring function - cross validated score
def cv_score(model, x, y, scoring='accuracy', cv=3, n_jobs=3):
    val = cross_validate(model,
                         x,
                         y=y,
                         scoring=scoring,
                         cv=cv,
                         n_jobs=n_jobs)['test_score'].mean()
    return val

# %%
def NB_BO(C, gamma):
    params = {"clf__C": C, "clf__gamma": gamma}
    model = Pipeline([('Embedding', CountVectorizer()),
                         ('Feature Transform', TfidfTransformer()),
                         ('clf', SVC(C=C, gamma=gamma, kernel='rbf', class_weight='balanced'))])
    score = cv_score(model, x_a, y_a, n_jobs=3)
    return score

# %%
SVC_BO = BayesianOptimization(NB_BO,
                             {"C": (1,10), "gamma": (1e-3,1)})

# %%
SVC_BO.maximize(n_iter=10)
# Out:
# Initialization
# -----------------------------------------------------
#  Step |   Time |      Value |         C |     gamma |
#     1 | 00m15s |    0.77705 |    3.8785 |    0.3399 |
#     2 | 00m11s |    0.76946 |    9.2171 |    0.0173 |
#     3 | 00m12s |    0.77192 |    7.6075 |    0.4388 |
#     4 | 00m12s |    0.75228 |    4.7362 |    0.8961 |
#     5 | 00m13s |    0.76946 |    9.6120 |    0.5340 |
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         C |     gamma |
#     6 | 00m17s |    0.28642 |    1.0000 |    0.0010 |
#     7 | 00m19s |    0.19384 |    5.4560 |    0.0010 |
#     8 | 00m16s |    0.74715 |    2.5784 |    1.0000 |
#     9 | 00m18s |    0.74670 |    8.4897 |    1.0000 |
#    10 | 00m18s |    0.74692 |    3.6777 |    1.0000 |
#    11 | 00m16s |    0.74670 |    6.6774 |    1.0000 |
#    12 | 00m17s |    0.28642 |    2.6417 |    0.0010 |
#    13 | 00m17s |    0.75094 |    1.0000 |    1.0000 |
# ...
